# %%
import mlflow
experiment_name = "timeseries_project_forecasting"
mlflow.set_experiment(experiment_name)
# Out:
# 2026/06/23 13:01:17 INFO mlflow.tracking.fluent: Experiment with name 'timeseries_project_forecasting' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/home/anuarsantoyo/Projects/Projects/MasterSchool/TimeSeriesProject_Jun26/mlruns/2', creation_time=1782212477672, effective_trace_archival_retention=None, experiment_id='2', last_update_time=1782212477672, lifecycle_stage='active', name='timeseries_project_forecasting', tags={}, trace_location=None, workspace='default'>

# %%
with mlflow.start_run(run_name="Test 3"):
    mlflow.log_param("model_type", "test")
    mlflow.log_metric("mse", 20)
    mlflow.log_metric("r2", .7)
